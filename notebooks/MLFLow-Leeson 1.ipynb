# %%
import mlflow
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# set the experiment id
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment(experiment_id="417363239085935913")

mlflow.autolog()
# Out:
# 2025/12/03 15:00:07 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.

# %%
db = sklearn.datasets.load_diabetes()

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# 2025/12/03 15:00:10 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1ed1410a0fba4495888b540bb7307306', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/12/03 15:00:14 INFO mlflow.tracking._tracking_service.client: 🏃 View run glamorous-gull-341 at: http://localhost:5000/#/experiments/417363239085935913/runs/1ed1410a0fba4495888b540bb7307306.
# 2025/12/03 15:00:14 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/417363239085935913.

# %%
mlflow.end_run()

# %%
with mlflow.start_run(): 

    mlflow.set_tags({"my_tag": "my_value"})
    mlflow.log_params({"n_stimators": 101})
    mlflow.log_metrics({"mse": 5})

mlflow.set_tags({"my_tag_2": "my_value_2"})
# Out:
# 2025/12/03 15:00:19 INFO mlflow.tracking._tracking_service.client: 🏃 View run resilient-bird-693 at: http://localhost:5000/#/experiments/417363239085935913/runs/67c2b47016a6468cb2322e95f02eac33.
# 2025/12/03 15:00:19 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/417363239085935913.
